# %%
import pandas as pd

df = pd.read_csv("Placement_Data_Full_Class.csv")

df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.shape
# Out:
# (215, 15)

# %%
df.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df['status'].value_counts()
# Out:
# status
# Placed        148
# Not Placed     67
# Name: count, dtype: int64

# %%
(df['status'].value_counts(normalize=True)*100)
# Out:
# status
# Placed        68.837209
# Not Placed    31.162791
# Name: proportion, dtype: float64

# %%
df['gender'].value_counts()
# Out:
# gender
# M    139
# F     76
# Name: count, dtype: int64

# %%
df['salary'].mean()
# Out:
# np.float64(288655.4054054054)

# %%
import matplotlib.pyplot as plt

df['status'].value_counts().plot(kind='bar')

plt.title("Placed vs Not Placed Students")
plt.xlabel("Status")
plt.ylabel("Count")

plt.show()

# %%
df[df['status']=='Placed']['degree_p'].mean()
# Out:
# np.float64(68.74054054054054)

# %%
df[df['status']=='Not Placed']['degree_p'].mean()
# Out:
# np.float64(61.13417910447761)

# %%
import matplotlib.pyplot as plt

df.groupby('status')['degree_p'].mean().plot(kind='bar')

plt.title("Average Degree Percentage by Placement Status")
plt.xlabel("Status")
plt.ylabel("Average Degree Percentage")

plt.show()

# %%
df[df['status']=='Placed']['etest_p'].mean()
# Out:
# np.float64(73.23804054054054)

# %%
df[df['status']=='Not Placed']['etest_p'].mean()
# Out:
# np.float64(69.5879104477612)

# %%
ax = df.groupby('status')['etest_p'].mean().plot(kind='bar')

for p in ax.patches:
    ax.annotate(
        f'{p.get_height():.2f}',
        (p.get_x() + p.get_width()/2, p.get_height()),
        ha='center',
        va='bottom'
    )

plt.show()

# %%
pd.crosstab(df['workex'], df['status'])
# Out:
# status  Not Placed  Placed
# workex
# No              57      84
# Yes             10      64

# %%
pd.crosstab(df['workex'], df['status']).plot(kind='bar')
# Out:
# <Axes: xlabel='workex'>

# %%
df.groupby('status')[['ssc_p','hsc_p','degree_p','etest_p','mba_p']].mean()
# Out:
#                 ssc_p      hsc_p   degree_p    etest_p      mba_p
# status
# Not Placed  57.544030  58.395522  61.134179  69.587910  61.612836
# Placed      71.721486  69.926554  68.740541  73.238041  62.579392

# %% [markdown]
# # Placement Analysis Findings
#
# 1. Placement Rate = 68.84%
#
# 2. Students with work experience had an 86.5% placement rate.
#
# 3. Average Degree Percentage:
#    - Placed: 68.74%
#    - Not Placed: 61.13%
#
# 4. Average Employability Test Score:
#    - Placed: 73.24
#    - Not Placed: 69.59
#
# 5. SSC and HSC percentages showed stronger differences than MBA percentage.
#
# Conclusion:
# Work Experience, SSC Percentage, HSC Percentage, and Degree Percentage appear to be important placement factors.
